# %% [markdown]
# **SurfaceRF Signal Recognition Training and Test workbook**

# %%
# TensorFlow and tf.keras
import tensorflow as tf

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.5.0

# %%
train_signal_array = np.load('/content/drive/MyDrive/Colab Notebooks/train_signal_array.npy', encoding='bytes')

test_signal_array = np.load('/content/drive/MyDrive/Colab Notebooks/test_signal_array.npy', encoding='bytes')

# %%
test_labels = np.load('/content/drive/MyDrive/Colab Notebooks/test_labels12000_array.npy', encoding = 'bytes')
train_labels = np.load('/content/drive/MyDrive/Colab Notebooks/train_labels18000_array.npy', encoding='bytes')

# %%
train_signal_array.shape
# Out:
# (18000, 256, 1)

# %%
plt.figure()
plt.plot(train_signal_array[0])
plt.show()
